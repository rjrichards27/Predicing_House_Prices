# %%
import pandas as pd
import numpy as np
from pathlib import Path
import zipfile


#importing the california data
PARENT = "Predicting_House_Prices"
path = Path(PARENT).parent / "../Data/cleaned_data.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0  stateId  countyId  cityId  is_bankOwned  is_forAuction  \
# 0           1        9       189   36958             0              0
# 1           2        9       190   36958             0              0
# 2           3        9       191   36958             0              0
# 3           5        9       193   36958             0              0
# 4           6        9       194   36958             0              0
#
#              event     price  livingArea lotAreaUnits  ...  parking  \
# 0  Listed for sale  675000.0      1671.0         sqft  ...        1
# 1  Listed for sale  649000.0      1414.0        Acres  ...        1
# 2  Listed for sale  599000.0      1336.0         sqft  ...        1
# 3  Listed for sale  575000.0      1413.0         sqft  ...        1
# 4  Listed for sale  888000.0      2278.0         sqft  ...        1
#
#    garageSpaces  hasGarage     levels  pool  spa isNewConstruction  \
# ...

# %%
#extracting the prices (our ys)
y_values = data["price"]
y_values
# Out:
# 0        675000.0
# 1        649000.0
# 2        599000.0
# 3        575000.0
# 4        888000.0
#            ...
# 33738    100000.0
# 33739    254900.0
# 33740    350000.0
# 33741    379000.0
# 33742    337900.0
# Name: price, Length: 33743, dtype: float64

# %%
#removing the Unamed:0 column and the price
data2 = data.drop(columns=
    [
        "Unnamed: 0",
        "price",
        "county"

    ]
)

data2.sample(15)
# Out:
#        stateId  countyId  cityId  is_bankOwned  is_forAuction  \
# 8672         9    172304   20288             0              0
# 30838       16    319306   32777             0              0
# 30133       16    279903    4782             0              0
# 24356        9    115330   19379             0              0
# 3862         9     74038   47019             0              0
# 13463        9    268508  396550             0              0
# 7239         9    140567   44406             0              0
# 23635        9    102612   32540             0              0
# 18705        9     28418   20288             0              0
# 20348        9     52121   20288             0              0
# 2248         9     42919   20328             0              0
# 14563        9    289082   13072             0              0
# 4273         9     79561   53655             0              0
# 31242       16      6551   32626             0              0
# ...

# %%
#standardizing the numeric variables

#variables to be standardized: livingArea, bathrooms, bedrooms, buildingArea, garageSpaces
#variables to be ohe: stateId , countyId, cityId, event, levels, homeType
#variables that are binary but are currently ints: is_bankOwned, is_forAuction, parking, hasGarage, pool, spa, isNewConstruction, isNewConstruction

data2.dtypes
# Out:
# stateId                int64
# countyId               int64
# cityId                 int64
# is_bankOwned           int64
# is_forAuction          int64
# event                 object
# livingArea           float64
# lotAreaUnits          object
# bathrooms            float64
# bedrooms             float64
# buildingArea         float64
# parking                int64
# garageSpaces         float64
# hasGarage              int64
# levels                object
# pool                   int64
# spa                    int64
# isNewConstruction      int64
# hasPetsAllowed         int64
# homeType              object
# dtype: object
