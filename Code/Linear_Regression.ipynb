# %% [markdown]
# ### Linear Regression Model
# This notebook uses the train and validation model data to train a linear regression model on the training data. I will first use the default parameters in the model and then use optimal parameters generated by a random rearch.

# %%
#importing the data
import pandas as pd
import numpy as np
from pathlib import Path

# %%
#importing the data
PARENT = "Predicing_House_Prices"
path = Path(PARENT).parent / "../Data/X_train_model2.csv"
X_train_model2 = pd.read_csv(path)

path2 = Path(PARENT).parent / "../Data/X_valid_model2.csv"
X_valid_model2 = pd.read_csv(path2)

path3 = Path(PARENT).parent / "../Data/y_train_model2.csv"
y_train_model2 = pd.read_csv(path3)

path4 = Path(PARENT).parent / "../Data/y_valid_model2.csv"
y_valid_model2 = pd.read_csv(path4)

# %%
#dropping unnamed column
X_train_model2 = X_train_model2.drop(columns="Unnamed: 0")
X_valid_model2 = X_valid_model2.drop(columns="Unnamed: 0")
y_train_model2 = y_train_model2.drop(columns="Unnamed: 0")
y_valid_model2 = y_valid_model2.drop(columns="Unnamed: 0")

# %%
#training the default linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_reg1 = LinearRegression().fit(X_train_model2, y_train_model2)

# %%
#getting the mean squared error and R^2

#y predictions on the validation data
preds= lin_reg1.predict(X_valid_model2)

print("Mean Squared Error:", format(mean_squared_error(y_valid_model2, preds)))
print("R Squared:", format(lin_reg1.score(X_valid_model2, y_valid_model2)))
# Out:
# Mean Squared Error: 4.152894233082195e+30
# R Squared: -1.226869361830285e+18

# %%
# random search for parameters

from sklearn.model_selection import RandomizedSearchCV
import random

random.seed(3467)
# run randomized search
lin_reg2 = LinearRegression(
    normalize= False,
    n_jobs=None
).fit(X_train_model2, y_train_model2)

#intializing possible parameters
params = {
    "fit_intercept": [True, False],
    "copy_X": [True, False],
    "positive": [True, False]
}
#number of iterations
n_iter_search = 400
random_search = RandomizedSearchCV(
    lin_reg2, param_distributions=params, 
    n_iter=n_iter_search, 
    cv= 3, n_jobs = -1
)
#fitting the random search
random_search.fit(X_train_model2, y_train_model2)
#printing the results
rand_opt = random_search.best_params_
print(rand_opt)
# Out:
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 8 is smaller than n_iter=400. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# /Users/rachelrichards/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# {'positive': True, 'fit_intercept': False, 'copy_X': True}

# %%
#fitting the model with random search parameters
lin_reg3 = LinearRegression(positive= True, fit_intercept=False, copy_X= True,
    n_jobs=None).fit(X_train_model2, y_train_model2)

# %%
#getting the mean squared error and R^2

#y predictions on the validation data
preds2= lin_reg3.predict(X_valid_model2)

print("Mean Squared Error:", format(mean_squared_error(y_valid_model2, preds2)))
print("R Squared:", format(lin_reg3.score(X_valid_model2, y_valid_model2)))
# Out:
# Mean Squared Error: 1709983475856.7566
# R Squared: 0.49482789158160845

# %% [markdown]
# I will now fit a model with less features. I picked the features that I think would have a strong effect on house price and limited the data to only those features.

# %%
#looking at all of the columns
for t in X_train_model2.columns:
    print(t)
# Out:
# yearBuilt
# livingArea
# bathrooms
# bedrooms
# parking
# garageSpaces
# hasGarage
# pool
# spa
# isNewConstruction
# hasPetsAllowed
# state_CA
# state_GA
# city_"oneals"
# city_abbeville
# city_acampo
# city_acton
# city_acworth
# city_adairsville
# city_adel
# city_adelanto
# city_adin
# city_adrian
# city_agoura
# city_agoura hills
# city_agua dulce
# city_ahwahnee
# city_ailey
# city_alameda
# city_alamo
# city_alapaha
# city_albany
# city_albion
# city_alderpoint
# city_alhambra
# city_aliso viejo
# city_allenhurst
# city_alma
# city_alpaugh
# city_alpharetta
# city_alpine
# city_alta
# city_alta loma
# city_altadena
# city_alto
# city_alturas
# city_alviso
# city_amador city
# city_american canyon
# city_americus
# city_anaheim
# city_anaheim hills
# city_anderson
# city_angels camp
# city_angelus oaks
# city_angwin
# city_annapolis
# city_antelope
# city_antioch
# city_apple valley
# city_applegate
# city_appling
# city_aptos
# city_arabi
# city_aragon
# city_arcadia
# city_arcata
# city_armuchee
# city_arnold
# city_arnoldsville
# city_arrowbear lake
# city_arrowhead
# city_arroyo grande
# city_artesia
# city_arvin
# city_ashburn
# city_atascadero
# city_athens
# city_atherton
# city_atlanta
# city_atwater
# city_auberry
# city_auburn
# city_augusta
# city_austell
# city_avalon
# city_ave
# city_avenal
# city_avila beach
# city_avondale est
# city_avondale estates
# city_azusa
# city_baconton
# city_badger
# city_bakersfield
# city_baldwin
# city_baldwin park
# city_ball ground
# city_ballico
# city_bangor
# city_barnesville
# city_barstow
# city_bartow
# city_barwick
# city_bass lake
# city_bassett
# city_baxley
# city_bay point
# city_beaumont
# city_beckwourth
# city_bell
# city_bell canyon
# city_bell gardens
# city_bella vista
# city_bellflower
# city_belmont
# city_belvedere
# city_belvedere tiburon
# city_ben lomond
# city_benicia
# city_benton
# city_berkeley
# city_berkeley lake
# city_bermuda dunes
# city_berry creek
# city_bethel island
# city_bethlehem
# city_beverly hills
# city_big bear
# city_big bear city
# city_big bear lake
# city_big canoe
# city_big creek
# city_big pine
# city_big river
# city_big sur
# city_biggs
# city_biola
# city_bishop
# city_blackshear
# city_blairsden
# city_blairsden graeagle
# city_blairsville
# city_blocksburg
# city_bloomingdale
# city_bloomington
# city_blue ridge
# city_blythe
# city_bodega bay
# city_bodfish
# city_bogart
# city_bonaire
# city_bonita
# city_bonsall
# city_boonville
# city_boron
# city_borrego springs
# city_boston
# city_boulder creek
# city_boulevard
# city_bowdon
# city_bowersville
# city_bowman
# city_box springs
# city_bradbury
# city_bradley
# city_braselton
# city_brawley
# city_brea
# city_bremen
# city_brentwood
# city_bridgeport
# city_bridgeville
# city_brisbane
# city_brookdale
# city_brookfield
# city_brookhaven
# city_brooklet
# city_brooks
# city_browns valley
# city_brownsville
# city_brunswick
# city_buchanan
# city_buckhead
# city_bucks lake
# city_buellton
# city_buena park
# city_buena vista
# city_buford
# city_burbank
# city_burlingame
# city_burney
# city_burnt ranch
# city_burson
# city_butler
# city_butte meadows
# city_byron
# city_cabazon
# city_cadwell
# city_calabasas
# city_calexico
# city_calhoun
# city_caliente
# city_california city
# city_calimesa
# city_calipatria
# city_calistoga
# city_calpine
# city_camarillo
# city_cambria
# city_cameron park
# city_camilla
# city_camino
# city_camp meeker
# city_campbell
# city_campo
# city_canby
# city_canoga park
# city_canon
# city_canton
# city_cantua creek
# city_canyon country
# city_canyon dam
# city_canyon lake
# city_capistrano beach
# city_capitola
# city_cardiff
# city_cardiff by the sea
# city_carlsbad
# city_carlton
# city_carmel
# city_carmel by the sea
# city_carmel valley
# city_carmichael
# city_carnelian bay
# city_carnesville
# city_carpinteria
# city_carrollton
# city_carson
# city_cartersville
# city_caruthers
# city_casmalia
# city_cassel
# city_castaic
# city_castro valley
# city_cataula
# city_cathedral city
# city_catheys valley
# city_cave spring
# city_cayucos
# city_cazadero
# city_cedar glen
# city_cedarpines park
# city_cedartown
# city_cedarville
# city_centerville
# city_ceres
# city_cerritos
# city_challenge
# city_chamblee
# city_chatsworth
# city_chattahoochee hills
# city_cherry log
# city_chester
# city_chickamauga
# city_chico
# city_chino
# city_chino hills
# city_chowchilla
# city_chula
# city_chula vista
# city_citrus heights
# city_claremont
# city_clarkesville
# city_clarksburg
# city_clarkston
# city_claxton
# city_clayton
# city_clearlake
# city_clearlake oaks
# city_clements
# city_clermont
# city_cleveland
# city_clio
# city_cloverdale
# city_clovis
# city_clyo
# city_coachella
# city_coalinga
# city_coarsegold
# city_cobb
# city_cochran
# city_cohutta
# city_colbert
# city_cold springs
# city_coleville
# city_colfax
# city_college park
# city_collins
# city_colton
# city_columbia
# city_columbus
# city_colusa
# city_comer
# city_commerce
# city_comptche
# city_compton
# city_concord
# city_conley
# city_conyers
# city_cool
# city_coolidge
# city_copperopolis
# city_corcoran
# city_cordele
# city_cornelia
# city_corning
# city_corona
# city_corona del mar
# city_coronado
# city_corte madera
# city_costa mesa
# city_cotati
# city_coto de caza
# city_cottonwood
# city_coulterville
# city_courtland
# city_covelo
# city_covina
# city_covington
# city_covington mill
# city_crandall
# city_crawford
# city_crawfordville
# city_crescent city
# city_crescent mills
# city_crestline
# city_crestmore
# city_creston
# city_crockett
# city_crowley lake
# city_crows landing
# city_cucamonga
# city_cudahy
# city_culloden
# city_culver city
# city_culver cty
# city_cumming
# city_cupertino
# city_cusseta
# city_cutler
# city_cypress
# city_dacula
# city_dahlonega
# city_dallas
# city_dalton
# city_daly city
# city_dana point
# city_dana pt
# city_danielsville
# city_danville
# city_darien
# city_davenport
# city_davis
# city_davis creek
# city_davisboro
# city_dawsonville
# city_decatur
# city_del mar
# city_delano
# city_delhi
# city_demorest
# city_denair
# city_denton
# city_descanso
# city_desert hot springs
# city_dewy rose
# city_dexter
# city_diablo
# city_diamond bar
# city_diamond springs
# city_dillard
# city_dinuba
# city_dixon
# city_dobbins
# city_doerun
# city_doraville
# city_dorris
# city_dos palos
# city_dos rios
# city_douglas
# city_douglas city
# city_douglas flat
# city_douglasville
# city_downey
# city_downieville
# city_doyle
# city_dry branch
# city_duarte
# city_dublin
# city_ducor
# city_duluth
# city_dulzura
# city_dunlap
# city_dunnigan
# city_dunsmuir
# city_dunwoody
# city_durham
# city_dutch flat
# city_eagle rock
# city_eagleville
# city_earlimart
# city_earp
# city_east dublin
# city_east ellijay
# city_east garrison
# city_east palo alto
# city_east point
# city_eastanollee
# city_eastman
# city_eatonton
# city_echo lake
# city_edison
# city_edwards
# city_el cajon
# city_el centro
# city_el cerrito
# city_el dorado
# city_el dorado hills
# city_el granada
# city_el macero
# city_el monte
# city_el nido
# city_el segundo
# city_el sobrante
# city_elberton
# city_elizabeth lake
# city_elk
# city_elk creek
# city_elk grove
# city_elko
# city_ellaville
# city_ellenwood
# city_ellerslie
# city_ellijay
# city_elverta
# city_emerson
# city_emeryville
# city_emigrant gap
# city_encinitas
# city_encino
# city_epworth
# city_escalon
# city_escondido
# city_esparto
# city_etiwanda
# city_etna
# city_eureka
# city_evans
# city_exeter
# city_fair oaks
# city_fair oaks ranch
# city_fairburn
# city_fairfax
# city_fairfield
# city_fairmount
# city_fall river mills
# city_fallbrook
# city_farmersville
# city_farmington
# city_fawnskin
# city_fayetteville
# city_fellows
# city_felton
# city_ferndale
# city_fiddletown
# city_fillmore
# city_fish camp
# city_fitzgerald
# city_fleming
# city_flintstone
# city_flovilla
# city_flowery branch
# city_folkston
# city_folsom
# city_fontana
# city_foothill ranch
# city_forbestown
# city_forest falls
# city_forest knolls
# city_forest park
# city_forest ranch
# city_foresthill
# city_forestville
# city_forsyth
# city_fort bragg
# city_fort jones
# city_fort oglethorpe
# city_fort valley
# city_fortson
# city_fortuna
# city_foster city
# city_fountain valley
# city_fowler
# city_franklin
# city_frazier park
# city_fremont
# city_french gulch
# city_fresno
# city_friant
# city_fullerton
# city_gainesville
# city_galt
# city_gamma gulch
# city_garberville
# city_garden city
# city_garden grove
# city_garden valley
# city_gardena
# city_garfield
# city_gasquet
# city_gay
# city_georgetown
# city_gerber
# city_geyserville
# city_gillsville
# city_gilroy
# city_glen ellen
# city_glencoe
# city_glendale
# city_glendora
# city_glenn
# city_glennville
# city_glenwood
# city_goleta
# city_good hope
# city_gordon
# city_graeagle
# city_granada hills
# city_grand terrace
# city_granite bay
# city_grantville
# city_grass valley
# city_graton
# city_gray
# city_grayson
# city_green valley lake
# city_greenbrae
# city_greenfield
# city_greensboro
# city_greenville
# city_greenwood
# city_grenada
# city_gridley
# city_griffin
# city_grizzly flats
# city_groveland
# city_grover beach
# city_grovetown
# city_gualala
# city_guerneville
# city_gustine
# city_guyton
# city_hacienda heights
# city_haddock
# city_hahira
# city_half moon bay
# city_hamilton
# city_hamilton city
# city_hammil valley
# city_hampton
# city_hanford
# city_hapeville
# city_happy camp
# city_harbor city
# city_harlem
# city_harmony
# city_harrison
# city_hartwell
# city_hawaiian gardens
# city_hawkinsville
# city_hawthorne
# city_hayfork
# city_hayward
# city_hazlehurst
# city_healdsburg
# city_heber
# city_helen
# city_helendale
# city_hemet
# city_hephzibah
# city_herald
# city_hercules
# city_herlong
# city_hermosa beach
# city_hesperia
# city_hiawassee
# city_hickman
# city_hidden hills
# city_highland
# city_hillsborough
# city_hilmar
# city_hinesville
# city_hinkley
# city_hiram
# city_hogansville
# city_hollister
# city_holtville
# city_homeland
# city_homer
# city_homerville
# city_hook creek tract
# city_hoopa
# city_hopland
# city_hornbrook
# city_hortense
# city_hoschton
# city_hughson
# city_hull
# city_huntington beach
# city_huntington lake
# city_huntington park
# city_huron
# city_hydesville
# city_idyllwild
# city_igo
# city_imperial
# city_imperial beach
# city_independence
# city_indian wells
# city_indio
# city_inglewood
# city_inverness
# city_inyokern
# city_ione
# city_irvine
# city_isleton
# city_ivanhoe
# city_ivey
# city_jackson
# city_jacumba
# city_jamestown
# city_jamul
# city_janesville
# city_jasper
# city_jefferson
# city_jeffersonville
# city_jekyll island
# city_jenkinsburg
# city_jenner
# city_jesup
# city_jewell
# city_johannesburg
# city_johns creek
# city_johnsville
# city_jonesboro
# city_joshua tree
# city_julian
# city_juliette
# city_june lake
# city_jurupa valley
# city_kathleen
# city_keene
# city_kelseyville
# city_kennesaw
# city_kensington
# city_kentfield
# city_kenwood
# city_kerman
# city_kernville
# city_keyes
# city_keysville
# city_king city
# city_kings beach
# city_kingsburg
# city_kingsland
# city_klamath
# city_klamath river
# city_kneeland
# city_knights landing
# city_knoxville
# city_la canada flintridge
# city_la crescenta
# city_la fayette
# city_la grange
# city_la habra
# city_la habra heights
# city_la honda
# city_la jolla
# city_la mesa
# city_la mirada
# city_la palma
# city_la puente
# city_la quinta
# city_la verne
# city_ladera ranch
# city_lafayette
# city_lagrange
# city_laguna beach
# city_laguna hills
# city_laguna niguel
# city_laguna woods
# city_lagunitas
# city_lake almanor
# city_lake arrowhead
# city_lake city
# city_lake elsinore
# city_lake forest
# city_lake gregory
# city_lake hughes
# city_lake isabella
# city_lake los angeles
# city_lake park
# city_lake sherwood
# city_lakehead
# city_lakeland
# city_lakemont
# city_lakeport
# city_lakeshore
# city_lakeside
# city_lakewood
# city_lamont
# city_lancaster
# city_landers
# city_larkspur
# city_lathrop
# city_laton
# city_lavonia
# city_lawndale
# city_lawrenceville
# city_laytonville
# city_le grand
# city_lebec
# city_leesburg
# city_leggett
# city_lemon grove
# city_lenox
# city_leslie
# city_lewiston
# city_lexington
# city_lilburn
# city_lincoln
# city_lincolnton
# city_linden
# city_lindsay
# city_lithia springs
# city_lithonia
# city_little river
# city_littlerock
# city_live oak
# city_livermore
# city_livingston
# city_lizella
# city_llano
# city_lockeford
# city_locust grove
# city_lodi
# city_loganville
# city_loleta
# city_loma linda
# city_loma mar
# city_lomita
# city_lompoc
# city_lone pine
# city_long barn
# city_long beach
# city_lookout mountain
# city_loomis
# city_los alamitos
# city_los alamos
# city_los altos
# city_los altos hills
# city_los angeles
# city_los banos
# city_los gatos
# city_los molinos
# city_los olivos
# city_los osos
# city_louisville
# city_lower lake
# city_lucerne
# city_lucerne valley
# city_ludowici
# city_lula
# city_luthersville
# city_lyerly
# city_lyndon
# city_lynwood
# city_lyons
# city_lytle creek
# city_mableton
# city_macdoel
# city_macon
# city_mad river
# city_madera
# city_madison
# city_magalia
# city_malibu
# city_mammoth lakes
# city_manchester
# city_manhattan beach
# city_manor
# city_mansfield
# city_manteca
# city_manton
# city_marble hill
# city_maricopa
# city_marietta
# city_marina
# city_marina del rey
# city_mariposa
# city_markleeville
# city_marshallville
# city_martin
# city_martinez
# city_marysville
# city_mather
# city_mauk
# city_maxwell
# city_maysville
# city_maywood
# city_mc caysville
# city_mc farland
# city_mc rae
# city_mc rae helena
# city_mcarthur
# city_mccloud
# city_mcdonough
# city_mckinleyville
# city_meadow valley
# city_meadow vista
# city_meansville
# city_mecca
# city_mendocino
# city_menifee
# city_menlo
# city_menlo park
# city_mentone
# city_merced
# city_meridian
# city_merritt st
# city_metter
# city_mi wuk village
# city_middletown
# city_midland
# city_midpines
# city_midville
# city_midway
# city_midway city
# city_milan
# city_mill creek
# city_mill valley
# city_millbrae
# city_milledgeville
# city_millen
# city_millville
# city_milner
# city_milpitas
# city_milton
# city_mineral
# city_mineral bluff
# city_mira loma
# city_miramonte
# city_mission hills
# city_mission viejo
# city_modesto
# city_mojave
# city_mokelumne hill
# city_molena
# city_monroe
# city_monrovia
# city_montague
# city_montara
# city_montclair
# city_monte rio
# city_montebello
# city_montecito
# city_monterey
# city_monterey park
# city_montezuma
# city_montgomery creek
# city_monticello
# city_montrose
# city_moorpark
# city_moraga
# city_moreland
# city_moreno valley
# city_morgan hill
# city_morganton
# city_morongo valley
# city_morro bay
# city_morrow
# city_moss beach
# city_moss landing
# city_moultrie
# city_mount airy
# city_mount baldy
# city_mount shasta
# city_mount vernon
# city_mountain center
# city_mountain city
# city_mountain ranch
# city_mountain view
# city_mt baldy
# city_murphys
# city_murrayville
# city_murrieta
# city_myers flat
# city_nahunta
# city_napa
# city_nashville
# city_national city
# city_naylor
# city_needles
# city_nelson
# city_nevada city
# city_new cuyama
# city_newark
# city_newberry springs
# city_newborn
# city_newbury park
# city_newcastle
# city_newhall
# city_newman
# city_newnan
# city_newport beach
# city_newport coast
# city_nicasio
# city_nice
# city_nicholls
# city_nicholson
# city_niland
# city_nipomo
# city_norco
# city_norcross
# city_norman park
# city_north fork
# city_north highlands
# city_north hills
# city_north hollywood
# city_north san juan
# city_north tustin
# city_northridge
# city_norwalk
# city_novato
# city_nuevo
# city_oak glen
# city_oak park
# city_oak run
# city_oak view
# city_oakdale
# city_oakhurst
# city_oakland
# city_oakley
# city_oakman
# city_oakwood
# city_occidental
# city_oceano
# city_oceanside
# city_ochlocknee
# city_ocilla
# city_odum
# city_oglethorpe
# city_ojai
# city_olancha
# city_old station
# city_olivehurst
# city_olympic valley
# city_ontario
# city_onyx
# city_orange
# city_orange cove
# city_orangevale
# city_orcutt
# city_oregon house
# city_orinda
# city_orland
# city_oro grande
# city_orosi
# city_oroville
# city_oxford
# city_oxnard
# city_pacheco
# city_pacific grove
# city_pacific palisades
# city_pacifica
# city_pacoima
# city_pala
# city_palm desert
# city_palm springs
# city_palmdale
# city_palmetto
# city_palo alto
# city_palo cedro
# city_palomar mountain
# city_palos verdes estates
# city_palos verdes peninsula
# city_panorama city
# city_paradise
# city_paramount
# city_parlier
# city_pasadena
# city_paso robles
# city_patterson
# city_pauma valley
# city_pavo
# city_paynes creek
# city_peachtree city
# city_peachtree corners
# city_pearblossom
# city_pebble beach
# city_pelham
# city_pembroke
# city_penn valley
# city_penngrove
# city_penryn
# city_perkins
# city_perris
# city_perry
# city_pescadero
# city_petaluma
# city_petrolia
# city_phelan
# city_phillips ranch
# city_philo
# city_pico rivera
# city_piedmont
# city_pilot hill
# city_pine grove
# city_pine lake
# city_pine mountain club
# city_pine valley
# city_pinole
# city_pinon hills
# city_pioneer
# city_pioneertown
# city_piru
# city_pismo beach
# city_pittsburg
# city_pixley
# city_placentia
# city_placerville
# city_plains
# city_plainville
# city_planada
# city_platina
# city_playa del rey
# city_playa vista
# city_pleasant grove
# city_pleasant hill
# city_pleasanton
# city_plymouth
# city_point arena
# city_point reyes station
# city_pollock pines
# city_pomona
# city_pooler
# city_pope valley
# city_port hueneme
# city_port wentworth
# city_porter ranch
# city_porterdale
# city_porterville
# city_portola
# city_portola valley
# city_posey
# city_potrero
# city_potter valley
# city_poway
# city_powder springs
# city_pt arena
# city_pt hueneme
# city_pt reyes station
# city_pt wentworth
# city_quail valley
# city_quartz hill
# city_quincy
# city_quitman
# city_rabun gap
# city_rackerby
# city_rail road flat
# city_ramona
# city_ranchita
# city_rancho cordova
# city_rancho cucamonga
# city_rancho mirage
# city_rancho mission viejo
# city_rancho palos verdes
# city_rancho santa fe
# city_randsburg
# city_ranger
# city_rayle
# city_raymond
# city_red bluff
# city_redcrest
# city_redding
# city_redlands
# city_redondo beach
# city_redwood city
# city_redwood valley
# city_reedley
# city_reidsville
# city_resaca
# city_rescue
# city_reseda
# city_rex
# city_reynolds
# city_rialto
# city_riceboro
# city_richland
# city_richmond
# city_richmond hill
# city_richvale
# city_ridgecrest
# city_rimforest
# city_rimrock
# city_rincon
# city_ringgold
# city_rio dell
# city_rio linda
# city_rio oso
# city_rio vista
# city_ripon
# city_rising fawn
# city_riverbank
# city_riverdale
# city_riverside
# city_rochelle
# city_rock spring
# city_rockledge
# city_rocklin
# city_rockmart
# city_rocky face
# city_rocky ford
# city_rodeo
# city_rohnert park
# city_rolling hills
# city_rome
# city_roopville
# city_rosamond
# city_rosemead
# city_roseville
# city_ross
# city_rossville
# city_roswell
# city_rough and ready
# city_round mountain
# city_rowland heights
# city_royston
# city_running springs
# city_rutledge
# city_rydal
# city_sacramento
# city_saint helena
# city_saint marys
# city_saint simons island
# city_sale city
# city_salida
# city_salinas
# city_salyer
# city_san andreas
# city_san anselmo
# city_san bernardino
# city_san bruno
# city_san carlos
# city_san clemente
# city_san diego
# city_san dimas
# city_san fernando
# city_san francisco
# city_san gabriel
# city_san geronimo
# city_san jacinto
# city_san joaquin
# city_san jose
# city_san juan bautista
# city_san juan capistrano
# city_san leandro
# city_san lorenzo
# city_san lucas
# city_san luis obispo
# city_san marcos
# city_san marino
# city_san martin
# city_san mateo
# city_san miguel
# city_san pablo
# city_san pedro
# city_san rafael
# city_san ramon
# city_san simeon
# city_san ysidro
# city_sandersville
# city_sandy springs
# city_sanger
# city_santa ana
# city_santa barbara
# city_santa clara
# city_santa clarita
# city_santa cruz
# city_santa fe springs
# city_santa margarita
# city_santa maria
# city_santa monica
# city_santa paula
# city_santa rosa
# city_santa rosa valley
# city_santa ynez
# city_santa ysabel
# city_santee
# city_saratoga
# city_saugus
# city_sausalito
# city_sautee nacoochee
# city_savannah
# city_scottdale
# city_scotts valley
# city_screven
# city_sea island
# city_sea ranch
# city_seal beach
# city_seaside
# city_sebastopol
# city_seiad valley
# city_selma
# city_senoia
# city_shady dale
# city_shafter
# city_shandon
# city_sharpsburg
# city_shasta lake
# city_shaver lake
# city_sheridan
# city_sherman oaks
# city_shingle springs
# city_shingletown
# city_sierra city
# city_sierra madre
# city_signal hill
# city_silver creek
# city_silverado
# city_silverado canyon
# city_simi valley
# city_sky valley
# city_skyforest
# city_sloughhouse
# city_smith river
# city_smithville
# city_smyrna
# city_snelling
# city_snellville
# city_social circle
# city_soda springs
# city_solana beach
# city_soledad
# city_solvang
# city_somerset
# city_somis
# city_sonoma
# city_sonora
# city_soperton
# city_soquel
# city_soulsbyville
# city_south dos palos
# city_south el monte
# city_south fulton
# city_south gate
# city_south lake tahoe
# city_south pasadena
# city_south san francisco
# city_sparks
# city_sparta
# city_spring valley
# city_springfield
# city_springville
# city_squaw valley
# city_standish
# city_stanford
# city_stanton
# city_stapleton
# city_statenville
# city_statesboro
# city_stephens
# city_stevenson ranch
# city_stevinson
# city_stinson beach
# city_stirling city
# city_stockbridge
# city_stockton
# city_stone mountain
# city_strawberry
# city_strawberry valley
# city_studio city
# city_suches
# city_sugar hill
# city_sugar valley
# city_sugarloaf
# city_suisun city
# city_summerland
# city_summerville
# city_sun city
# city_sun valley
# city_sunland
# city_sunnyvale
# city_sunol
# city_sunset beach
# city_susanville
# city_sutter
# city_sutter creek
# city_suwanee
# city_swainsboro
# city_sycamore
# city_sylmar
# city_sylvania
# city_sylvester
# city_taft
# city_tahoe city
# city_tahoe vista
# city_tahoma
# city_talbotton
# city_talking rock
# city_tallapoosa
# city_talmage
# city_talmo
# city_tarrytown
# city_tarzana
# city_taylorsville
# city_tehachapi
# city_temecula
# city_temple
# city_temple city
# city_templeton
# city_tennille
# city_terra bella
# city_the sea ranch
# city_thermal
# city_thomasville
# city_thomson
# city_thousand oaks
# city_thousand palms
# city_three rivers
# city_tiburon
# city_tifton
# city_tiger
# city_tignall
# city_toccoa
# city_tollhouse
# city_toluca lake
# city_topanga
# city_torrance
# city_townsend
# city_trabuco canyon
# city_tracy
# city_traver
# city_trenton
# city_tres pinos
# city_trinidad
# city_trinity center
# city_trion
# city_trona
# city_truckee
# city_tucker
# city_tujunga
# city_tulare
# city_tulelake
# city_tunnel hill
# city_tuolumne
# city_turin
# city_turlock
# city_tustin
# city_twain
# city_twain harte
# city_twentynine palms
# city_twin bridges
# city_twin city
# city_twin peaks
# city_ty ty
# city_tybee island
# city_tyrone
# city_ukiah
# city_unadilla
# city_union city
# city_union point
# city_union pt
# city_upatoi
# city_upland
# city_upper lake
# city_uvalda
# city_vacaville
# city_val verde
# city_valdosta
# city_valencia
# city_vallejo
# city_valley center
# city_valley glen
# city_valley of enchantment
# city_valley springs
# city_valley village
# city_van nuys
# city_venice
# city_ventura
# city_victorville
# city_vidalia
# city_vienna
# city_villa park
# city_villa rica
# city_visalia
# city_vista
# city_volcano
# city_waco
# city_wadley
# city_waleska
# city_walker
# city_wallace
# city_walnut
# city_walnut creek
# city_walnut grove
# city_warm springs
# city_warner robins
# city_warner springs
# city_warrenton
# city_warthen
# city_warwick
# city_wasco
# city_washington
# city_waterford
# city_watkinsville
# city_watsonville
# city_waverly
# city_waverly hall
# city_waycross
# city_waynesboro
# city_waynesville
# city_weaverville
# city_weott
# city_west covina
# city_west hills
# city_west hollywood
# city_west point
# city_west pt
# city_west sacramento
# city_westchester
# city_westlake
# city_westlake village
# city_westminster
# city_westport
# city_westwood
# city_wheatland
# city_white
# city_white oak
# city_white plains
# city_whitesburg
# city_whitethorn
# city_whitewater
# city_whitmore
# city_whittier
# city_wildomar
# city_wildwood
# city_willacoochee
# city_williamson
# city_willits
# city_willow creek
# city_willows
# city_wilmington
# city_wilseyville
# city_wilton
# city_winchester
# city_winder
# city_windsor
# city_winnetka
# city_winston
# city_winters
# city_winterville
# city_winton
# city_wishon
# city_wofford heights
# city_woodacre
# city_woodbine
# city_woodbridge
# city_woodbury
# city_woodlake
# city_woodland
# city_woodland hills
# city_woodside
# city_woodstock
# city_woodville
# city_woody
# city_wrens
# city_wrightsville
# city_wrightwood
# city_yatesville
# city_yermo
# city_yorba linda
# city_yorkville
# city_yosemite national park
# city_young harris
# city_yountville
# city_yreka
# city_yuba city
# city_yucaipa
# city_yucca valley
# city_zebulon
# city_zenia
# event_Listed for sale
# event_Listing removed
# event_Pending sale
# event_Price change
# event_Sold
# lotAreaUnits_Acres
# lotAreaUnits_sqft
# levels_one level
# levels_others
# levels_split level
# levels_two levels
# homeType_APARTMENT
# homeType_CONDO
# homeType_MULTI_FAMILY
# homeType_SINGLE_FAMILY
# homeType_TOWNHOUSE
# county_Alameda County
# county_Alpine County
# county_Amador County
# county_Appling County
# county_Atkinson County
# county_Bacon County
# county_Baldwin County
# county_Banks County
# county_Barrow County
# county_Bartow County
# county_Ben Hill County
# county_Berrien County
# county_Bibb County
# county_Bleckley County
# county_Brantley County
# county_Brooks County
# county_Bryan County
# county_Bulloch County
# county_Burke County
# county_Butte County
# county_Butts County
# county_Calaveras County
# county_Camden County
# county_Candler County
# county_Carroll County
# county_Catoosa County
# county_Charlton County
# county_Chatham County
# county_Chattahoochee County
# county_Chattooga County
# county_Cherokee County
# county_Clarke County
# county_Clayton County
# county_Clinch County
# county_Cobb County
# county_Coffee County
# county_Colquitt County
# county_Columbia County
# county_Colusa County
# county_Contra Costa County
# county_Cook County
# county_Coweta County
# county_Crawford County
# county_Crisp County
# county_Dade County
# county_Dawson County
# county_Dekalb County
# county_Del Norte County
# county_Dodge County
# county_Dooly County
# county_Dougherty County
# county_Douglas County
# county_Echols County
# county_Effingham County
# county_El Dorado County
# county_Elbert County
# county_Emanuel County
# county_Evans County
# county_Fannin County
# county_Fayette County
# county_Floyd County
# county_Forsyth County
# county_Franklin County
# county_Fresno County
# county_Fulton County
# county_Gilmer County
# county_Glenn County
# county_Glynn County
# county_Gordon County
# county_Grady County
# county_Greene County
# county_Gwinnett County
# county_Habersham County
# county_Hall County
# county_Hancock County
# county_Haralson County
# county_Harris County
# county_Hart County
# county_Heard County
# county_Henry County
# county_Houston County
# county_Humboldt County
# county_Imperial County
# county_Inyo County
# county_Irwin County
# county_Jackson County
# county_Jasper County
# county_Jeff Davis County
# county_Jefferson County
# county_Jenkins County
# county_Johnson County
# county_Jones County
# county_Kern County
# county_Kings County
# county_Lake County
# county_Lamar County
# county_Lanier County
# county_Lassen County
# county_Laurens County
# county_Lee County
# county_Liberty County
# county_Lincoln County
# county_Long County
# county_Los Angeles County
# county_Lowndes County
# county_Lumpkin County
# county_Macon County
# county_Madera County
# county_Madison County
# county_Marin County
# county_Marion County
# county_Mariposa County
# county_McDuffie County
# county_McIntosh County
# county_Mendocino County
# county_Merced County
# county_Meriwether County
# county_Mitchell County
# county_Modoc County
# county_Mono County
# county_Monroe County
# county_Monterey County
# county_Montgomery County
# county_Morgan County
# county_Murray County
# county_Muscogee County
# county_Napa County
# county_Nevada County
# county_Newton County
# county_Oconee County
# county_Oglethorpe County
# county_Orange County
# county_Paulding County
# county_Peach County
# county_Pickens County
# county_Pierce County
# county_Pike County
# county_Placer County
# county_Plumas County
# county_Polk County
# county_Pulaski County
# county_Putnam County
# county_Rabun County
# county_Richmond County
# county_Riverside County
# county_Rockdale County
# county_Sacramento County
# county_San Benito County
# county_San Bernardino County
# county_San Diego County
# county_San Francisco County
# county_San Joaquin County
# county_San Luis Obispo County
# county_San Mateo County
# county_Santa Barbara County
# county_Santa Clara County
# county_Santa Cruz County
# county_Schley County
# county_Screven County
# county_Shasta County
# county_Sierra County
# county_Siskiyou County
# county_Solano County
# county_Sonoma County
# county_Spalding County
# county_Stanislaus County
# county_Stephens County
# county_Stewart County
# county_Sumter County
# county_Sutter County
# county_Talbot County
# county_Taliaferro County
# county_Tattnall County
# county_Taylor County
# county_Tehama County
# county_Telfair County
# county_Thomas County
# county_Tift County
# county_Toombs County
# county_Towns County
# county_Treutlen County
# county_Trinity County
# county_Troup County
# county_Tulare County
# county_Tuolumne County
# county_Turner County
# county_Twiggs County
# county_Union County
# county_Upson County
# county_Ventura County
# county_Walker County
# county_Walton County
# county_Ware County
# county_Warren County
# county_Washington County
# county_Wayne County
# county_Wheeler County
# county_White County
# county_Whitfield County
# county_Wilcox County
# county_Wilkes County
# county_Wilkinson County
# county_Worth County
# county_Yolo County
# county_Yuba County

# %%
# subsetting for only necessary vairables
X_train_model3 = X_train_model2.filter(["livingArea", "bathrooms", "bedrooms", "garageSpaces", 
"pool", "isNewConstruction", "state_CA", "state_GA"])
X_valid_model3 = X_valid_model2.filter(["livingArea", "bathrooms", "bedrooms", "garageSpaces", 
"pool", "isNewConstruction", "state_CA", "state_GA"])

# %%
#fitting the model with limited features
lin_reg4 = LinearRegression(positive= True, fit_intercept=False, copy_X= True,
    n_jobs=None).fit(X_train_model3, y_train_model2)

# %%
#getting the mean squared error and R^2

#y predictions on the validation data
preds4= lin_reg4.predict(X_valid_model3)

print("Mean Squared Error:", format(mean_squared_error(y_valid_model2, preds4)))
print("R Squared:", format(lin_reg4.score(X_valid_model3, y_valid_model2)))
# Out:
# Mean Squared Error: 2305960452157.2104
# R Squared: 0.3187613096892473
